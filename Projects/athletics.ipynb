# %%
import pandas as pd

# %%
df_athlete = pd.read_csv('/Users/augustincablant/Desktop/Kaggle/athlete_events.csv')
df_regions = pd.read_csv('/Users/augustincablant/Desktop/Kaggle/noc_regions.csv')
athle = df_athlete[df_athlete['Sport']=='Athletics'] 
athle['Event'].unique()
liste_athle = ["Athletics Men's 1,500 metres","Athletics Men's 5,000 metres","Athletics Men's 800 metres",
               "Athletics Men's 10,000 metres", "Athletics Women's 3,000 metres", "Athletics Men's 3,000 metres Steeplechase",
               "Athletics Women's 5,000 metres", "Athletics Women's 10,000 metres", "Athletics Women's 1,500 metres",
               "Athletics Women's 800 metres", "Athletics Women's 3,000 metres Steeplechase", 
               "Athletics Men's Cross-Country, Individual", "Athletics Men's 5 mile"]
athle[athle['Event'].isin(liste_athle)]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 98          34    Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0
# 148         55                   Antonio Abadia Beci   M  26.0   170.0
# 190         86               Jos Manuel Abascal Gmez   M  22.0   182.0
# 191         86               Jos Manuel Abascal Gmez   M  26.0   182.0
# 241        117                           Maher Abbas   M  22.0   178.0
# ...        ...                                   ...  ..   ...     ...
# 270809  135437     Mara Teresa "Maite" Ziga Domnguez   F  31.0   167.0
# 270912  135480                          Geeta Zutshi   F  23.0   167.0
# 270913  135480                          Geeta Zutshi   F  27.0   167.0
# 271027  135531  Sabine Beate Zwiener (-Jauchstetter)   F  24.0   172.0
# 271044  135543            Victor Andrew "Vic" Zwolak   M  25.0   175.0
#
#         Weight           Team  NOC        Games  Year  Season            City  \
# ...
